# %%
import pandas as pd
from sqlalchemy import create_engine
from pandas_profiling import ProfileReport

#engine = create_engine('postgresql://aplicacion:aplicacion@localhost:5432/snr')

# %%
df_1 = pd.read_excel(r'C:\opt\work\upra\prototipo\procesamiento\empresas.xlsx', sheet_name='1000_empresas')
df_1.head()
# Out:
#    No.          NIT                   RAZON_SOCIAL       SUPERVISOR  \
# 0    1  899,999,068                  ECOPETROL S.A  SUPERFINANCIERA
# 1    1  890,200,656          PALMAS DEL CESAR S.A.  SUPERSOCIEDADES
# 2    2  830,095,213       ORGANIZACIÓN TERPEL S.A.  SUPERFINANCIERA
# 3    3  900,112,515  REFINERIA DE CARTAGENA S.A.S.  SUPERSOCIEDADES
# 4    4  890,900,608            ALMACENES EXITO S A  SUPERFINANCIERA
#
#                   REGIÓN DEPARTAMENTO DOMICILIO         CIUDAD DOMICILIO  \
# 0  Bogotá - Cundinamarca            BOGOTA D.C.  BOGOTA-D.C.-BOGOTA D.C.
# 1       Centro - Oriente              SANTANDER    BUCARAMANGA-SANTANDER
# 2  Bogotá - Cundinamarca            BOGOTA D.C.  BOGOTA-D.C.-BOGOTA D.C.
# 3        Costa Atlántica                BOLIVAR        CARTAGENA-BOLIVAR
# 4              Antioquia              ANTIOQUIA       ENVIGADO-ANTIOQUIA
#
#                                                 CIIU           MACROSECTOR  \
# ...

# %%
df_1.shape
# Out:
# (1000, 20)

# %%
df_1 = df_1[["NIT", "RAZON_SOCIAL"]]
df_1.head()
# Out:
#            NIT                   RAZON_SOCIAL
# 0  899,999,068                  ECOPETROL S.A
# 1  890,200,656          PALMAS DEL CESAR S.A.
# 2  830,095,213       ORGANIZACIÓN TERPEL S.A.
# 3  900,112,515  REFINERIA DE CARTAGENA S.A.S.
# 4  890,900,608            ALMACENES EXITO S A

# %%
df_1 = df_1.rename(columns= {'NIT': 'nit' , 'RAZON_SOCIAL': 'empresa'}    )
df_1.head()
# Out:
#            nit                        empresa
# 0  899,999,068                  ECOPETROL S.A
# 1  890,200,656          PALMAS DEL CESAR S.A.
# 2  830,095,213       ORGANIZACIÓN TERPEL S.A.
# 3  900,112,515  REFINERIA DE CARTAGENA S.A.S.
# 4  890,900,608            ALMACENES EXITO S A

# %%
df_1["fuente"] = "1000_empresas"
df_1.head()
# Out:
#            nit                        empresa         fuente
# 0  899,999,068                  ECOPETROL S.A  1000_empresas
# 1  890,200,656          PALMAS DEL CESAR S.A.  1000_empresas
# 2  830,095,213       ORGANIZACIÓN TERPEL S.A.  1000_empresas
# 3  900,112,515  REFINERIA DE CARTAGENA S.A.S.  1000_empresas
# 4  890,900,608            ALMACENES EXITO S A  1000_empresas

# %%
df_2 = pd.read_excel(r'C:\opt\work\upra\prototipo\procesamiento\empresas.xlsx', sheet_name='transp_valle_cauca')
df_2.head()
# Out:
#    codigodanemunicipio origen  numeroempresa             empresa  \
# 0                76001   Cali             18   SULTANA DEL VALLE
# 1                76001   Cali             18   SULTANA DEL VALLE
# 2                76001   Cali             14  TRANS INDUSTRIALES
# 3                76001   Cali             15  COOPETRANS PALMIRA
# 4                76001   Cali             15  COOPETRANS PALMIRA
#
#             telefono                     ruta clasevehiculo  \
# 0  6535141 - 6684001        CANDELARIA CAVASA        BUSETA
# 1  6535141 - 6684001                ANDELARIA        BUSETA
# 2            6611182  YUMBO CARRETERA ANTIGUA        BUSETA
# 3            3969408                     ROZO        BUSETA
# 4            3969408                     ROZO        BUSETA
#
#                    lugarsalida       destino  codigodanemunicipiodestino  \
# 0  TERMINAL DE TRANSPORTE CALI    CANDELARIA                     76130.0
# ...

# %%
df_2 = df_2[["empresa"]]
df_2["fuente"] = "transporte"
df_2["nit"] = ""
df_2.head()
# Out:
#               empresa      fuente nit
# 0   SULTANA DEL VALLE  transporte
# 1   SULTANA DEL VALLE  transporte
# 2  TRANS INDUSTRIALES  transporte
# 3  COOPETRANS PALMIRA  transporte
# 4  COOPETRANS PALMIRA  transporte

# %%
df_3 = pd.read_excel(r'C:\opt\work\upra\prototipo\procesamiento\empresas.xlsx', sheet_name='rups')
df_3.head()
# Out:
#   DEPARTAMENTO_PRESTACION MUNICIPIO_PRESTACION  \
# 0                     NaN                  NaN
# 1                     NaN                  NaN
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
#
#                           SERVICIO ESTADO  \
# 0  Inscripción Oficio Delegada AAA    NaN
# 1  Inscripción Oficio Delegada AAA    NaN
# 2  Inscripción Oficio Delegada AAA    NaN
# 3  Inscripción Oficio Delegada AAA    NaN
# 4  Inscripción Oficio Delegada AAA    NaN
#
#                                              empresa          nit  \
# 0  JUNTA ADMINISTRADORA DEL ACUEDUCTO VEREDA SAN ...   999999028-
# 1                  ASOCIACION DE USUARIOS LOS BALSOS  932003408-3
# 2  JUNTA DE ACCION COMUNAL COMITE EMPRESARIAL ACU...    92099368-
# 3                JUNTA ADMINISTRADORA VEREDA BETANIA    91104958-
# 4                       ACUEDUCTO VEREDAL EL CARMELO    91103736-
#
# ...

# %%
df_3 = df_3[["empresa", "nit"]]
df_3["fuente"] = "rups"
df_3.head()
# Out:
#                                              empresa          nit fuente
# 0  JUNTA ADMINISTRADORA DEL ACUEDUCTO VEREDA SAN ...   999999028-   rups
# 1                  ASOCIACION DE USUARIOS LOS BALSOS  932003408-3   rups
# 2  JUNTA DE ACCION COMUNAL COMITE EMPRESARIAL ACU...    92099368-   rups
# 3                JUNTA ADMINISTRADORA VEREDA BETANIA    91104958-   rups
# 4                       ACUEDUCTO VEREDAL EL CARMELO    91103736-   rups

# %%
df_4 = pd.read_excel(r'C:\opt\work\upra\prototipo\procesamiento\empresas.xlsx', sheet_name='maritimo')
df_4.head()
# Out:
#                                             empresa  \
# 0  ABBAS CARGO AGENCIES SERVICES GROUP COLOMBIA SAS
# 1                             ABELARDO MINA MURILLO
# 2                 ADIELA GUMERSINDA REALPE VALENCIA
# 3                 ADIELA GUMERSINDA REALPE VALENCIA
# 4              ADUACARGA INTERNATIONAL LOGISTICS SA
#
#                              Nombre                 dirección_empresa  \
# 0          RUJANA DUQUE EDIN ALBERTO  CALLE 93 BIS #19-40 OFICINA 202
# 1              ABELARDO MINA MURILLO                    CALLE 3 5A 13
# 2  ADIELA GUMERSINDA REALPE VALENCIA         PUERTO PALMA LOCAL 4C-29
# 3  ADIELA GUMERSINDA REALPE VALENCIA         PUERTO PALMA LOCAL 4C-29
# 4      DORA MARIELA RODRIGUEZ GARZON                CALLE 142 51 A 23
#
#   telefono_empresa        Ciudad        tipo_de_empresa
# 0          4839605        Bogotá  INTERNACIONAL PUBLICO
# 1       241 188 47  Buenaventura       CABOTAJE PUBLICO
# 2       3127170714        Tumaco  INTERNACIONAL PUBLICO
# ...

# %%
df_4 = df_4[["empresa"]]
df_4["fuente"] = "maritimo"
df_4["nit"] = ""
df_4.head()
# Out:
#                                             empresa    fuente nit
# 0  ABBAS CARGO AGENCIES SERVICES GROUP COLOMBIA SAS  maritimo
# 1                             ABELARDO MINA MURILLO  maritimo
# 2                 ADIELA GUMERSINDA REALPE VALENCIA  maritimo
# 3                 ADIELA GUMERSINDA REALPE VALENCIA  maritimo
# 4              ADUACARGA INTERNATIONAL LOGISTICS SA  maritimo

# %%
df_5 = pd.read_excel(r'C:\opt\work\upra\prototipo\procesamiento\empresas.xlsx', sheet_name='fluvial')
df_5.head()
# Out:
#           nit                                            empresa  \
# 0  9006667594                AGENCIA DE VIAJES SELVATOUR  S.A.S.
# 1  8600000182  AGENCIA DE VIAJES Y TURISMO AVIATUR S.A.  "AVI...
# 2   184638119                             ALDINEBER HOYOS MURIEL
# 3  9004166208                            AQUAPARK GUATAPE S.A.S.
# 4   709512943                 ARISTIZABAL VILLEGAS OSCAR AUGUSTO
#
#                      DIRECCION        MUNICIPIO DEPARTAMENTO     TELÉFONO   \
# 0       CARRERA 11 N°8-66  L. 2         LETICIA      AMAZONAS  No registra
# 1                  AV 19 N°4-62     BOGOTA D.C.        BOGOTA      6356131
# 2  CALLE DEL COMERCIO CAUSARITO  PUERTO CARREÑO       VICHADA   3108032934
# 3              CALLE 31 N°31-37         GUATAPE     ANTIOQUIA      6145441
# 4       VIA PEÑOL GUATAPE Km 10         GUATAPE     ANTIOQUIA      8610650
#
#                  RIO                        ZONA DE OPERACIÓN
# ...

# %%
df_5 = df_5[["empresa", "nit"]]
df_5["fuente"] = "fluvial"
df_5.head()
# Out:
#                                              empresa         nit   fuente
# 0                AGENCIA DE VIAJES SELVATOUR  S.A.S.  9006667594  fluvial
# 1  AGENCIA DE VIAJES Y TURISMO AVIATUR S.A.  "AVI...  8600000182  fluvial
# 2                             ALDINEBER HOYOS MURIEL   184638119  fluvial
# 3                            AQUAPARK GUATAPE S.A.S.  9004166208  fluvial
# 4                 ARISTIZABAL VILLEGAS OSCAR AUGUSTO   709512943  fluvial

# %%
df_6 = pd.read_excel(r'C:\opt\work\upra\prototipo\procesamiento\empresas.xlsx', sheet_name='secop_ii_nit')
df_6.head()
# Out:
#                                       Nombre_Entidad  Nit_Entidad  \
# 0  ESTABLECIMIENTO PENITENCIARIO DE MEDIANA SEGUR...  816,001,832
# 1                    FONDO NACIONAL AMBIENTAL - ANLA  830,025,267
# 2                              ICBF REGIONAL GUAJIRA  899,999,239
# 3            MINISTERIO DE SALUD Y PROTECCIÓN SOCIAL  900,474,727
# 4                 DIRECCION NACIONAL DE INTELIGENCIA  900,475,460
#
#                  Departamento       Ciudad                     Localización  \
# 0                   Risaralda      Pereira  Colombia,  Risaralda ,  Pereira
# 1  Distrito Capital de Bogotá  No Definido         Colombia, Bogotá, Bogotá
# 2                  La Guajira  No Definido            Colombia,  La Guajira
# 3  Distrito Capital de Bogotá  No Definido         Colombia, Bogotá, Bogotá
# 4                 No Definido  No Definido                         Colombia
#
#       Orden                                         Sector       Rama  \
# ...

# %%
df_6a = df_6[["Nombre_Entidad", "Nit_Entidad"]]
df_6a = df_6a.rename(columns= {'Nit_Entidad': 'nit' , 'Nombre_Entidad': 'empresa'}    )
df_6a["fuente"] = "secop_ii_entidades"
df_6a.head()
# Out:
#                                              empresa          nit  \
# 0  ESTABLECIMIENTO PENITENCIARIO DE MEDIANA SEGUR...  816,001,832
# 1                    FONDO NACIONAL AMBIENTAL - ANLA  830,025,267
# 2                              ICBF REGIONAL GUAJIRA  899,999,239
# 3            MINISTERIO DE SALUD Y PROTECCIÓN SOCIAL  900,474,727
# 4                 DIRECCION NACIONAL DE INTELIGENCIA  900,475,460
#
#                fuente
# 0  secop_ii_entidades
# 1  secop_ii_entidades
# 2  secop_ii_entidades
# 3  secop_ii_entidades
# 4  secop_ii_entidades

# %%
df_6b = df_6[["Proveedor_Adjudicado", "Documento_Proveedor"]]
df_6b = df_6b.rename(columns= {'Documento_Proveedor': 'nit' , 'Proveedor_Adjudicado': 'empresa'}    )
df_6b["fuente"] = "secop_ii_proveedores"
df_6b.head()
# Out:
#                                              empresa          nit  \
# 0                                     TORENTINOS SAS    901188139
# 1                     SECURITY SOLUTIONS & EDUCATION    900310978
# 2               FUNDACION PUERTAS PARA EL DESARROLLO    900406972
# 3     MANUFACTURERA DE GRANDES COCINAS MGC & CIA SAS    830011157
# 4  UNIÓN TEMPORAL AXA COLPATRIA SEGUROS S.A.- MAP...  No Definido
#
#                  fuente
# 0  secop_ii_proveedores
# 1  secop_ii_proveedores
# 2  secop_ii_proveedores
# 3  secop_ii_proveedores
# 4  secop_ii_proveedores

# %%
frames = [df_1, df_2, df_3, df_4, df_5, df_6a, df_6b]

df_all = pd.concat(frames)
df_all.shape
# Out:
# (332060, 3)

# %%
df_all.head()
# Out:
#            nit                        empresa         fuente
# 0  899,999,068                  ECOPETROL S.A  1000_empresas
# 1  890,200,656          PALMAS DEL CESAR S.A.  1000_empresas
# 2  830,095,213       ORGANIZACIÓN TERPEL S.A.  1000_empresas
# 3  900,112,515  REFINERIA DE CARTAGENA S.A.S.  1000_empresas
# 4  890,900,608            ALMACENES EXITO S A  1000_empresas

# %%
df_all["nit"] = df_all['nit'].str.replace('[^\w\s]','')
df_all.head()
# Out:
#          nit                        empresa         fuente
# 0  899999068                  ECOPETROL S.A  1000_empresas
# 1  890200656          PALMAS DEL CESAR S.A.  1000_empresas
# 2  830095213       ORGANIZACIÓN TERPEL S.A.  1000_empresas
# 3  900112515  REFINERIA DE CARTAGENA S.A.S.  1000_empresas
# 4  890900608            ALMACENES EXITO S A  1000_empresas

# %%
df_all.drop_duplicates(  keep = 'first', inplace = True) 
df_all.shape
# Out:
# (47168, 3)

# %%
df_all["nit_len"]= df_all["nit"].str.len()

# %%
#df.to_sql('upra_linderos_8506', con=engine, if_exists='replace')

# %%
df_all.to_csv('empresas.tsv', sep = '\t', index=False)

# %%
profile = ProfileReport(df_all, title="Pandas Profiling Report")
profile
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-12-03 17:49:49.875540&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file("empresas_profile.html")

# %% [markdown]
# https://ucd-dnp.github.io/leila/

# %%
from leila.reporte import generar_reporte


generar_reporte(df_all)
# Out:
# No hay filas duplicadas
# No hay columnas duplicadas
# interval columns not set, guessing: ['nit_len']
# --------------------------------------------------------------------------------------------
# Se ha generado el reporte "C:\opt\work\upra\prototipo\perfilamiento_leila.html"
# 12:50:38 PM (00 min 10 seg)
# --------------------------------------------------------------------------------------------

# %%
df_all[df_all['nit_len']!=9]
# Out:
#                 nit                              empresa  \
# 0                                      SULTANA DEL VALLE
# 2                                     TRANS INDUSTRIALES
# 3                                     COOPETRANS PALMIRA
# 7                                               COOMEPAL
# 8                                       COOPETRANS TULUA
# ...             ...                                  ...
# 158762  No Definido                            INTERVIAL
# 158816   9007109843                        PEDRATOWN SAS
# 158841   8000447743        RÜEFLI DE LA TORRE & CIA LTDA
# 158887          NaN  CUIDAR CON CALIDEZ HUMANA IPS SAS -
# 158900   1022389919                  ALEJANDRA GUTIERREZ
#
#                       fuente  nit_len
# 0                 transporte      0.0
# 2                 transporte      0.0
# 3                 transporte      0.0
# 7                 transporte      0.0
# 8                 transporte      0.0
# ...                      ...      ...
# ...

# %%
df_nit9 = df_all[df_all['nit_len']==9]
profile = ProfileReport(df_nit9, title="Perfilamiento de datos UPRA - Transacciones registrales rurales")
profile
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-12-03 18:04:48.593330&quot;&gt;&lt;title&gt;Perfilamiento de datos UPRA - Transacciones registrales rurales&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file("empresas_nit9_profile.html")

# %%
df_nit9.to_csv('empresas_nit9.tsv', sep = '\t', index=False)

# %%
df_nit9 = pd.read_csv('empresas_nit9.tsv', sep = '\t')
df_nit9.shape
# Out:
# (24984, 4)

# %%
from contexto.limpieza import remover_acentos

df_nit9_sin_acentos = remover_acentos(df_nit9)
df_nit9_sin_acentos.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-4363b8131951> in <module>
#       2
#       3
# ----> 4 df_nit9_sin_acentos = remover_acentos(df_nit9)
#       5 df_nit9_sin_acentos.head()
#
# ~\AppData\Roaming\Python\Python38\site-packages\contexto\limpieza.py in remover_acentos(texto)
#      17     except NameError:
#      18         pass
# ---> 19     texto = unicodedata.normalize('NFD', texto)\
#      20         .encode('ascii', 'ignore')\
#      21         .decode("utf-8")
#
# TypeError: normalize() argument 2 must be str, not DataFrame

# %%
df_nit9['empresa'] = df_nit9['empresa'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
df_nit9.head()
# Out:
#          nit                        empresa         fuente  nit_len
# 0  899999068                  ECOPETROL S.A  1000_empresas      9.0
# 1  890200656          PALMAS DEL CESAR S.A.  1000_empresas      9.0
# 2  830095213       ORGANIZACION TERPEL S.A.  1000_empresas      9.0
# 3  900112515  REFINERIA DE CARTAGENA S.A.S.  1000_empresas      9.0
# 4  890900608            ALMACENES EXITO S A  1000_empresas      9.0

# %%
df_nit9.to_csv('empresas_nit9_sin_acentos.tsv', sep = '\t', index=False)

# %% [markdown]
# # Secop I

# %%
df_secop1 = pd.read_csv(r'C:\opt\work\upra\prototipo\procesamiento\SECOP_I.csv')
df_secop1.shape
# Out:
# (9456678, 72)

# %%
#df_secop1.columns
df_secop1.columns.values.tolist()
# Out:
# ['UID',
#  'Anno Cargue SECOP',
#  'Anno Firma del Contrato',
#  'Nivel Entidad',
#  'Orden Entidad',
#  'Nombre de la Entidad',
#  'NIT de la Entidad',
#  'Código de la Entidad',
#  'ID Tipo de Proceso',
#  'Tipo de Proceso',
#  'Estado del Proceso',
#  'Causal de Otras Formas de Contratacion Directa',
#  'ID Regimen de Contratacion',
#  'Regimen de Contratacion',
#  'ID Objeto a Contratar',
#  'Objeto a Contratar',
#  'Detalle del Objeto a Contratar',
#  'Tipo de Contrato',
#  'Municipio Obtencion',
#  'Municipio Entrega',
#  'Municipios Ejecucion',
#  'Fecha de Cargue en el SECOP',
#  'Numero de Constancia',
#  'Numero de Proceso',
#  'Numero del Contrato',
#  'Cuantia Proceso',
#  'ID Grupo',
#  'Nombre Grupo',
#  'ID Familia',
#  'Nombre Familia',
#  'ID Clase',
#  'Nombre Clase',
#  'ID Ajudicacion',
#  'Tipo Identifi del Contratista',
#  'Identificacion del Contratista',
#  'Nom Raz Social Contratista',
#  'Dpto y Muni Contratista',
#  'Tipo Doc Representante Legal',
# ...

# %%
pd.set_option('display.max_rows', 100)

# %%
df_secop1.dtypes
# Out:
# UID                                                object
# Anno Cargue SECOP                                   int64
# Anno Firma del Contrato                             int64
# Nivel Entidad                                      object
# Orden Entidad                                      object
# Nombre de la Entidad                               object
# NIT de la Entidad                                  object
# Código de la Entidad                                int64
# ID Tipo de Proceso                                  int64
# Tipo de Proceso                                    object
# Estado del Proceso                                 object
# Causal de Otras Formas de Contratacion Directa     object
# ID Regimen de Contratacion                        float64
# Regimen de Contratacion                            object
# ID Objeto a Contratar                               int64
# Objeto a Contratar                                 object
# ...

# %%
df_secop1.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9456678 entries, 0 to 9456677
# Data columns (total 72 columns):
#  #   Column                                          Dtype
# ---  ------                                          -----
#  0   UID                                             object
#  1   Anno Cargue SECOP                               int64
#  2   Anno Firma del Contrato                         int64
#  3   Nivel Entidad                                   object
#  4   Orden Entidad                                   object
#  5   Nombre de la Entidad                            object
#  6   NIT de la Entidad                               object
#  7   Código de la Entidad                            int64
#  8   ID Tipo de Proceso                              int64
#  9   Tipo de Proceso                                 object
#  10  Estado del Proceso                              object
#  11  Causal de Otras Formas de Contratacion Directa  object
# ...

# %%
df_secop_contratistas = df_secop1[["Tipo Identifi del Contratista", "Identificacion del Contratista", "Nom Raz Social Contratista"]]
df_secop_contratistas["tipo"] = "CONTRATISTA"

df_secop_contratistas = df_secop_contratistas.rename(columns= {'Tipo Identifi del Contratista': 'tipo_id' ,
                                              'Nom Raz Social Contratista': 'nombre', 
                                               'Identificacion del Contratista': "identificacion", 
                                           }    )


df_secop_contratistas.head()
# Out:
# <ipython-input-30-bc53b95e60d1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_secop_contratistas["tipo"] = "CONTRATISTA"
#                    tipo_id identificacion  \
# 0     Cédula de Ciudadanía     1061716186
# 1     Cédula de Ciudadanía     79.797.121
# 2     Cédula de Ciudadanía     1129582505
# 3  Nit de Persona Jurídica    900162365-2
# 4     Cédula de Ciudadanía     1079411237
#
#                                      nombre         tipo
# 0            EDITH JOHANA HUELGAS RODRÍGUEZ  CONTRATISTA
# 1            FREDY ENRIQUE RAMIREZ MARTINEZ  CONTRATISTA
# 2                     CARLOS MOSCOTE TAMARA  CONTRATISTA
# 3  CORPORACIÓN PLANETA AZUL LLANO ¿CORAZUL¿  CONTRATISTA
# ...

# %%
df_secop_representantes = df_secop1[["Tipo Doc Representante Legal", "Identific del Represen Legal", 
                                     "Nombre del Represen Legal", "Sexo RepLegal Entidad"]]
df_secop_representantes["tipo"] = "REPRESENTANTES"

df_secop_representantes = df_secop_representantes.rename(columns= {'Tipo Doc Representante Legal': 'tipo_id' ,
                                              'Nombre del Represen Legal': 'nombre', 
                                               'Identific del Represen Legal': "identificacion", 
                                               "Sexo RepLegal Entidad":"sexo"
                                           }    )


df_secop_representantes.head()
# Out:
# <ipython-input-31-9bd0111e8bbc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_secop_representantes["tipo"] = "REPRESENTANTES"
#                 tipo_id identificacion                             nombre  \
# 0  Cédula de Ciudadanía     1061716186     EDITH JOHANA HUELGAS RODRÍGUEZ
# 1  Cédula de Ciudadanía     79.797.121     FREDY ENRIQUE RAMIREZ MARTINEZ
# 2  Cédula de Ciudadanía     1129582502              CARLOS MOSCOTE TAMARA
# 3  Cédula de Ciudadanía     40.442.842          EDITH IRAIDA MÉNDEZ RIAÑO
# 4  Cédula de Ciudadanía     1079411237  MAHIRA ALEJANDRA CERQUERA PERDOMO
#
#             sexo            tipo
# 0  No registrado  REPRESENTANTES
# 1             ND  REPRESENTANTES
# 2             ND  REPRESENTANTES
# ...

# %%
frames = [df_secop_contratistas, df_secop_representantes]

df_secop_personas = pd.concat(frames)
df_secop_personas.shape
# Out:
# (18913356, 5)

# %%
df_secop_personas.head()
# Out:
#                    tipo_id identificacion  \
# 0     Cédula de Ciudadanía     1061716186
# 1     Cédula de Ciudadanía     79.797.121
# 2     Cédula de Ciudadanía     1129582505
# 3  Nit de Persona Jurídica    900162365-2
# 4     Cédula de Ciudadanía     1079411237
#
#                                      nombre         tipo sexo
# 0            EDITH JOHANA HUELGAS RODRÍGUEZ  CONTRATISTA  NaN
# 1            FREDY ENRIQUE RAMIREZ MARTINEZ  CONTRATISTA  NaN
# 2                     CARLOS MOSCOTE TAMARA  CONTRATISTA  NaN
# 3  CORPORACIÓN PLANETA AZUL LLANO ¿CORAZUL¿  CONTRATISTA  NaN
# 4         MAHIRA ALEJANDRA CERQUERA PERDOMO  CONTRATISTA  NaN

# %%
df_secop_personas.describe()
# Out:
#                      tipo_id identificacion       nombre            tipo  \
# count               18913356       18882166     18860791        18913356
# unique                    12        2649054      3331499               2
# top     Cédula de Ciudadanía    No Definido  No Definido  REPRESENTANTES
# freq                13251170        2564892      2564892         9456678
#
#            sexo
# count   9456678
# unique        5
# top          ND
# freq    7213325

# %%
df_secop_personas["identificacion_clean"] = df_secop_contratistas["identificacion"].str.replace('[^\d]','')
df_secop_personas.head()
# Out:
#                    tipo_id identificacion  \
# 0     Cédula de Ciudadanía     1061716186
# 1     Cédula de Ciudadanía     79.797.121
# 2     Cédula de Ciudadanía     1129582505
# 3  Nit de Persona Jurídica    900162365-2
# 4     Cédula de Ciudadanía     1079411237
#
#                                      nombre         tipo sexo  \
# 0            EDITH JOHANA HUELGAS RODRÍGUEZ  CONTRATISTA  NaN
# 1            FREDY ENRIQUE RAMIREZ MARTINEZ  CONTRATISTA  NaN
# 2                     CARLOS MOSCOTE TAMARA  CONTRATISTA  NaN
# 3  CORPORACIÓN PLANETA AZUL LLANO ¿CORAZUL¿  CONTRATISTA  NaN
# 4         MAHIRA ALEJANDRA CERQUERA PERDOMO  CONTRATISTA  NaN
#
#   identificacion_clean
# 0           1061716186
# 1             79797121
# 2           1129582505
# 3           9001623652
# 4           1079411237

# %%
df_secop_personas['nombre_clean'] = df_secop_personas['nombre'] .astype(str).map(str.upper)
df_secop_personas['nombre_clean'] = df_secop_personas['nombre_clean'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
df_secop_personas['nombre_clean'] = df_secop_personas['nombre_clean'].map(str.strip)
df_secop_personas.head()
# Out:
#                    tipo_id identificacion  \
# 0     Cédula de Ciudadanía     1061716186
# 1     Cédula de Ciudadanía     79.797.121
# 2     Cédula de Ciudadanía     1129582505
# 3  Nit de Persona Jurídica    900162365-2
# 4     Cédula de Ciudadanía     1079411237
#
#                                      nombre         tipo sexo  \
# 0            EDITH JOHANA HUELGAS RODRÍGUEZ  CONTRATISTA  NaN
# 1            FREDY ENRIQUE RAMIREZ MARTINEZ  CONTRATISTA  NaN
# 2                     CARLOS MOSCOTE TAMARA  CONTRATISTA  NaN
# 3  CORPORACIÓN PLANETA AZUL LLANO ¿CORAZUL¿  CONTRATISTA  NaN
# 4         MAHIRA ALEJANDRA CERQUERA PERDOMO  CONTRATISTA  NaN
#
#   identificacion_clean                            nombre_clean
# 0           1061716186          EDITH JOHANA HUELGAS RODRIGUEZ
# 1             79797121          FREDY ENRIQUE RAMIREZ MARTINEZ
# 2           1129582505                   CARLOS MOSCOTE TAMARA
# 3           9001623652  CORPORACION PLANETA AZUL LLANO CORAZUL
# ...

# %%
df_secop_personas.drop('identificacion', axis=1, inplace=True)
df_secop_personas.drop('nombre', axis=1, inplace=True)
df_secop_personas.shape
# Out:
# (18913356, 5)

# %%
df_secop_personas.head()
# Out:
#                    tipo_id         tipo sexo identificacion_clean  \
# 0     Cédula de Ciudadanía  CONTRATISTA  NaN           1061716186
# 1     Cédula de Ciudadanía  CONTRATISTA  NaN             79797121
# 2     Cédula de Ciudadanía  CONTRATISTA  NaN           1129582505
# 3  Nit de Persona Jurídica  CONTRATISTA  NaN           9001623652
# 4     Cédula de Ciudadanía  CONTRATISTA  NaN           1079411237
#
#                              nombre_clean
# 0          EDITH JOHANA HUELGAS RODRIGUEZ
# 1          FREDY ENRIQUE RAMIREZ MARTINEZ
# 2                   CARLOS MOSCOTE TAMARA
# 3  CORPORACION PLANETA AZUL LLANO CORAZUL
# 4       MAHIRA ALEJANDRA CERQUERA PERDOMO

# %%
df_secop_personas.drop_duplicates(  keep = 'first', inplace = True) 
df_secop_personas.shape
# Out:
# (6341385, 5)

# %%
df_secop_personas["identificacion_clean_len"]= df_secop_personas["identificacion_clean"].str.len()

# %%
df_secop_personas.to_csv('secop1_personas.tsv', sep = '\t', index=False)

# %%
profile = ProfileReport(df_secop_personas, title="Perfilamiento de datos UPRA - Personas SECOP 1")
profile.to_file("secop1_personas_profile.html")

# %%
df_secop_personas[df_secop_personas['tipo_id']=="Nit de Persona Natural"].head(5)
# Out:
#                    tipo_id         tipo sexo identificacion_clean  \
# 5   Nit de Persona Natural  CONTRATISTA  NaN            700109989
# 11  Nit de Persona Natural  CONTRATISTA  NaN            134625326
# 25  Nit de Persona Natural  CONTRATISTA  NaN              2558191
# 52  Nit de Persona Natural  CONTRATISTA  NaN            883059511
# 85  Nit de Persona Natural  CONTRATISTA  NaN             47427647
#
#                      nombre_clean
# 5   NATACHA CAROLINA OSPINA LOPEZ
# 11              BODEGA LA OFERTA.
# 25     HECTOR ARTURO ROZO MANCERA
# 52        FERMIN CONTRERAS SANTOS
# 85         HOLLMAN SAMBONI ADRADA

# %%
df_secop_personas[df_secop_personas['tipo_id']=="Cédula de Extranjería"].head(5)
# Out:
#                     tipo_id         tipo sexo identificacion_clean  \
# 202   Cédula de Extranjería  CONTRATISTA  NaN           1232392897
# 5216  Cédula de Extranjería  CONTRATISTA  NaN               360817
# 7948  Cédula de Extranjería  CONTRATISTA  NaN               432797
# 7957  Cédula de Extranjería  CONTRATISTA  NaN               546791
# 8070  Cédula de Extranjería  CONTRATISTA  NaN               454013
#
#                        nombre_clean
# 202    GERSON ADOLFO VITANARE GOMEZ
# 5216        GREGORIS SERRANO SIERRA
# 7948       RICARDO BARRIENTOS TRABA
# 7957         GREGORIO  AYALA  ROJAS
# 8070  JORGE TITO PEREZ DEL CASTILLO

# %%
df_secop_personas[df_secop_personas['tipo_id']=="Nit de Extranjería"].head(5)
# Out:
#                  tipo_id         tipo sexo identificacion_clean  \
# 1230  Nit de Extranjería  CONTRATISTA  NaN           8000552599
# 3721  Nit de Extranjería  CONTRATISTA  NaN            208672179
# 5253  Nit de Extranjería  CONTRATISTA  NaN           9003064761
# 5635  Nit de Extranjería  CONTRATISTA  NaN             63489246
# 5986  Nit de Extranjería  CONTRATISTA  NaN            900300084
#
#                                            nombre_clean  \
# 1230              CORPORACION PRODESARROLLO Y SEGURIDAD
# 3721                           EYMAQ PROJECT MANAGEMENT
# 5253                                   NEO MEDIOS S.A.S
# 5635                             EULALIA PACHECO TRIANA
# 5986  EMPRESA COOPERATIVA DE ACUEDUCTO ALCANTARILLAD...
#
#       identificacion_clean_len
# 1230                      10.0
# 3721                       9.0
# 5253                      10.0
# 5635                       8.0
# 5986                       9.0

# %%
df_secop_empresas= df_secop_personas.loc[(df_secop_personas['tipo_id']=="Nit de Persona Jurídica") &
                                            (df_secop_personas['identificacion_clean_len']== 9)
                                         ]
df_secop_empresas.head()
# Out:
#                     tipo_id         tipo sexo identificacion_clean  \
# 7   Nit de Persona Jurídica  CONTRATISTA  NaN            800027362
# 10  Nit de Persona Jurídica  CONTRATISTA  NaN            901245972
# 13  Nit de Persona Jurídica  CONTRATISTA  NaN            750825313
# 20  Nit de Persona Jurídica  CONTRATISTA  NaN            860028662
# 23  Nit de Persona Jurídica  CONTRATISTA  NaN            832004720
#
#                                          nombre_clean  \
# 7           ANDINA DE ILUMINACIONES S.A. ANDILUM S.A.
# 10                                CONSORCIO PROACTIVA
# 13  CARLOS ANDRES CASTRO MURILLO  FERREMUNDO COMER...
# 20                                     LAB BRANDS SAS
# 23        CORPORACION JOVENES OBRANDO PARA CREAR  JOC
#
#     identificacion_clean_len
# 7                        9.0
# 10                       9.0
# 13                       9.0
# 20                       9.0
# 23                       9.0

# %%
df_secop_empresas = df_secop_empresas[[ "identificacion_clean", "nombre_clean"]]
df_secop_empresas.head()
# Out:
#    identificacion_clean                                       nombre_clean
# 7             800027362          ANDINA DE ILUMINACIONES S.A. ANDILUM S.A.
# 10            901245972                                CONSORCIO PROACTIVA
# 13            750825313  CARLOS ANDRES CASTRO MURILLO  FERREMUNDO COMER...
# 20            860028662                                     LAB BRANDS SAS
# 23            832004720        CORPORACION JOVENES OBRANDO PARA CREAR  JOC

# %%
df_secop_empresas.shape
# Out:
# (438939, 2)

# %%
df_secop_empresas.drop_duplicates(  keep = 'first', inplace = True) 
df_secop_empresas.shape
# Out:
# (405778, 2)

# %%
df_secop_empresas = df_secop_empresas.rename(columns= {'identificacion_clean': 'nit' ,
                                              'nombre_clean': 'empresa'
                                           }    )

# %%
df_secop_empresas.to_csv('secop1_empresas.tsv', sep = '\t', index=False)

# %%
df_empresas_1 = pd.read_csv(r'C:\opt\work\upra\prototipo\empresas_nit9_sin_acentos.tsv',sep = '\t',)
df_empresas_1.head()
# Out:
#          nit                        empresa         fuente  nit_len
# 0  899999068                  ECOPETROL S.A  1000_empresas      9.0
# 1  890200656          PALMAS DEL CESAR S.A.  1000_empresas      9.0
# 2  830095213       ORGANIZACION TERPEL S.A.  1000_empresas      9.0
# 3  900112515  REFINERIA DE CARTAGENA S.A.S.  1000_empresas      9.0
# 4  890900608            ALMACENES EXITO S A  1000_empresas      9.0

# %%
df_empresas_1.drop('fuente', axis=1, inplace=True)
df_empresas_1.drop('nit_len', axis=1, inplace=True)

# %%
frames = [df_secop_empresas, df_empresas_1]
df_empresas_all = pd.concat(frames)
df_empresas_all.shape
# Out:
# (430762, 2)

# %%
df_empresas_all['empresa'] = df_empresas_all['empresa'].str.replace('[^\w\s]','')
df_empresas_all['empresa'] = df_empresas_all['empresa'].astype(str).map(str.upper)
df_empresas_all['empresa'] = df_empresas_all['empresa'].str.replace(',','').str.replace('.','').str.replace('  ',' ')
df_empresas_all['empresa'] = df_empresas_all['empresa'].replace('\n',' ', regex=True)
df_empresas_all['empresa'] = df_empresas_all['empresa'].replace('^\d+$','', regex=True)
df_empresas_all['empresa'] = df_empresas_all['empresa'].map(str.strip)
df_empresas_all.head()
# Out:
#           nit                                            empresa
# 7   800027362              ANDINA DE ILUMINACIONES SA ANDILUM SA
# 10  901245972                                CONSORCIO PROACTIVA
# 13  750825313  CARLOS ANDRES CASTRO MURILLO FERREMUNDO COMERC...
# 20  860028662                                     LAB BRANDS SAS
# 23  832004720         CORPORACION JOVENES OBRANDO PARA CREAR JOC

# %%
df_empresas_all.drop_duplicates(  keep = 'first', inplace = True) 
df_empresas_all.shape
# Out:
# (336945, 2)

# %%
df_empresas_all.to_csv('empresas_all.tsv', sep = '\t', index=False)

# %%
df_empresas_all_sin_nit = df_empresas_all[["empresa"]]
df_empresas_all_sin_nit = df_empresas_all_sin_nit.sort_values(by=['empresa'])
df_empresas_all_sin_nit.head(10)
# Out:
#         empresa
# 4933295
# 8190992
# 3128885
# 5476016
# 5522891
# 7849855
# 8369869
# 5753115
# 1421988
# 8641264

# %%
df_empresas_all_sin_nit.drop_duplicates(  keep = 'first', inplace = True) 
df_empresas_all_sin_nit.shape
# Out:
# (315878, 1)

# %%
df_empresas_all_sin_nit["empresa_len"]= df_empresas_all_sin_nit["empresa"].str.len() 
df_empresas_all_sin_nit.head()
# Out:
#                                                    empresa  empresa_len
# 4933295                                                               0
# 3148613                       0 2 CONVERGENCIA DIGITAL SAS           28
# 2911318                              0 ES 3 COMPUTERS LTDA           21
# 1516060                       0 INSTRUMENTOS CONTROLES S A           28
# 6123182  000PERATIVA DE CONSUMO Y MARKETING ENLACES DE ...           82

# %%
df_empresas_all_sin_nit = df_empresas_all_sin_nit.sort_values(by=['empresa_len'])
df_empresas_all_sin_nit = df_empresas_all_sin_nit[df_empresas_all_sin_nit['empresa_len']>2]
df_empresas_all_sin_nit.head()
# Out:
#         empresa  empresa_len
# 540539      ACJ            3
# 4124267     UNE            3
# 6943506     CIA            3
# 475228      BPR            3
# 8122131     FAO            3

# %%
df_empresas_all_sin_nit.drop('empresa_len', axis=1, inplace=True)
df_empresas_all_sin_nit = df_empresas_all_sin_nit.sort_values(by=['empresa'])
df_empresas_all_sin_nit.to_csv('empresas_all_sin_nit.tsv', sep = '\t', index=False)

# %% [markdown]
# # secop personas naturales

# %%
df_secop_cedulas= df_secop_personas.loc[(df_secop_personas['tipo_id']=="Cédula de Ciudadanía") 
                                         ]
df_secop_cedulas.drop('tipo_id', axis=1, inplace=True)
df_secop_cedulas.drop('tipo', axis=1, inplace=True)
df_secop_cedulas.drop('sexo', axis=1, inplace=True)
df_secop_cedulas.head()
# Out:
# C:\apps\miniconda3\envs\dataproc\lib\site-packages\pandas\core\frame.py:4160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#   identificacion_clean                       nombre_clean  \
# 0           1061716186     EDITH JOHANA HUELGAS RODRIGUEZ
# 1             79797121     FREDY ENRIQUE RAMIREZ MARTINEZ
# 2           1129582505              CARLOS MOSCOTE TAMARA
# 4           1079411237  MAHIRA ALEJANDRA CERQUERA PERDOMO
# 6           1007396404           ANYI YULIE MENDOZA LEYVA
#
#    identificacion_clean_len
# 0                      10.0
# 1                       8.0
# 2                      10.0
# 4                      10.0
# 6                      10.0

# %%
# Out:
# <ipython-input-148-8137785850c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_secop_cedulas["nombre_clean_len"]= df_secop_cedulas["nombre_clean"].str.len()

# %%
#df_secop_cedulas['empresa'] = df_secop_cedulas['empresa'].str.replace('[^\w\s]','')
df_secop_cedulas['nombre_clean'] = df_secop_cedulas['nombre_clean'].astype(str).map(str.upper)
df_secop_cedulas['nombre_clean'] = df_secop_cedulas['nombre_clean'].str.replace(',','').str.replace('.','').str.replace('  ',' ')
df_secop_cedulas['nombre_clean'] = df_secop_cedulas['nombre_clean'].replace('\n',' ', regex=True)
df_secop_cedulas['nombre_clean'] = df_secop_cedulas['nombre_clean'].replace('^\d+$','', regex=True)
# Out:
# <ipython-input-160-d8723f307741>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_secop_cedulas['nombre_clean'] = df_secop_cedulas['nombre_clean'].astype(str).map(str.upper)
# <ipython-input-160-d8723f307741>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_secop_cedulas['nombre_clean'] = df_secop_cedulas['nombre_clean'].str.replace(',','').str.replace('.','').str.replace('  ',' ')
# <ipython-input-160-d8723f307741>:4: SettingWithCopyWarning:
# ...

# %%
#df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('\d')].head()
# remover nombres con números
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('\d')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('/')].index, inplace = True) 
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('-')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('\(')].index, inplace = True) 
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('\)')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains(' SA ')].index, inplace = True) 
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains(' SAS ')].index, inplace = True) 
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains(' SA$')].index, inplace = True) 
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains(' SAS$')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('SERVICIO')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('PARA')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('NUMERO')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('PROPIETARIO')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('LTDA')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('LEGAL')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('EMPRESA')].index, inplace = True)
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains(' ESE ')].index, inplace = True)
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('REPRESENT')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('ASOCIACION')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('CORPORACION')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('FUNDACION')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('AUXILIAR')].index, inplace = True)

# %%
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('NACIONAL')].index, inplace = True)

# %%
#df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('^(?![a-zA-Z])')].head()
#df_secop_cedulas.head()

# remover filas con nombres que tienen caracteres especiales
df_secop_cedulas.drop(df_secop_cedulas[df_secop_cedulas['nombre_clean'].str.contains('^(?![a-zA-Z])')].index, inplace = True)

# %%
df_secop_cedulas.head()
# Out:
#         identificacion_clean nombre_clean  identificacion_clean_len  \
# 5252084             79808383   SISA ROQUE                       8.0
# 3424539             43380984   EL IMPERIO                       8.0
# 486845              59123333   YINA SPORT                       8.0
# 6517210            900853144   PINO RICCI                       9.0
# 4340212              5796091   RAUL PRADA                       7.0
#
#          nombre_clean_len
# 5252084                10
# 3424539                10
# 486845                 10
# 6517210                10
# 4340212                10

# %%
df_secop_cedulas["nombre_clean_len"]= df_secop_cedulas["nombre_clean"].str.len()                                 
                                             
df_secop_cedulas= df_secop_cedulas.loc[(df_secop_cedulas['identificacion_clean_len']<11) &
                                            (df_secop_cedulas['nombre_clean_len']>9) &  (df_secop_cedulas['nombre_clean_len']<40)
                                         ]

df_secop_cedulas.drop_duplicates(  keep = 'first', inplace = True)

# %%
#df_secop_cedulas['nombre_clean_word_count'] =  df_secop_cedulas['nombre_clean'].str.split().stack().value_counts()

from collections import Counter
df_secop_cedulas['nombre_clean_word_count'] = df_secop_cedulas['nombre_clean'].apply(lambda x: len(x.split()))
df_secop_cedulas.head()
# Out:
#         identificacion_clean nombre_clean  identificacion_clean_len  \
# 5252084             79808383   SISA ROQUE                       8.0
# 390695             800047829   JAIME MORA                       9.0
# 4780282              4088442   URIEL RUIZ                       7.0
# 4762352            891501348   SURY CASSO                       9.0
# 4433638            900597916   OFFIR ARCE                       9.0
#
#          nombre_clean_len  nombre_clean_word_count
# 5252084                10                        2
# 390695                 10                        2
# 4780282                10                        2
# 4762352                10                        2
# 4433638                10                        2

# %%
df_secop_cedulas= df_secop_cedulas.loc[(df_secop_cedulas['nombre_clean_word_count']>1) 
                                           
                                         ]

# %%
df_secop_cedulas = df_secop_cedulas.sort_values(by=['nombre_clean_len'])

# %%
df_secop_cedulas.to_csv('secop_personas_cedula.tsv', sep = '\t', index=False)

# %%
df_secop_cedulas_nombres = df_secop_cedulas[["nombre_clean"]]
df_secop_cedulas_nombres.head()
# Out:
#         nombre_clean
# 5252084   SISA ROQUE
# 390695    JAIME MORA
# 4780282   URIEL RUIZ
# 4762352   SURY CASSO
# 4433638   OFFIR ARCE

# %%
df_secop_cedulas_nombres.shape
# Out:
# (2527893, 1)

# %%
df_secop_cedulas_nombres.drop_duplicates(  keep = 'first', inplace = True) 
df_secop_cedulas_nombres.shape
# Out:
# <ipython-input-231-c7876c9cce52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_secop_cedulas_nombres.drop_duplicates(  keep = 'first', inplace = True)
# (2061416, 1)

# %%
df_secop_cedulas_nombres.to_csv('secop_personas_cedula_nombres.tsv', sep = '\t', index=False)
